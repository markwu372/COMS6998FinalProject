# %%
# %matplotlib inline
from IPython.display import Image

# %%
import os
def create_folder(path):
    if not os.path.isdir(path):
        os.mkdir(path)

# %%
if 'google.colab' in str(get_ipython()):
    print('Cloning code base to colab....')
    # !git clone https://github.com/ZefangWang/generalization_to_OOD_category_viewpoint_combinations.git
    # !cd generalization_to_OOD_category_viewpoint_combinations/utils && bash download_biased_cars.sh
    CODE_ROOT = "generalization_to_OOD_category_viewpoint_combinations/"
else:
    CODE_ROOT = '..'
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6202028_2020-04-06_VQYHXAH9.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6302999_2020-04-07_6TRPHPKK.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6302999_2020-04-07_6TRPHPKK.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6198284_2020-04-06_8FD7V68U.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6198284_2020-04-06_8FD7V68U.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6299900_2020-04-07_97E1HH8L.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6299900_2020-04-07_97E1HH8L.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6296562_2020-04-07_AN4ET85U.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6296562_2020-04-07_AN4ET85U.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6299889_2020-04-07_97E1HH8L.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6299889_2020-04-07_97E1HH8L.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6207655_2020-04-06_G8PUBZJZ.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6207655_2020-04-06_G8PUBZJZ.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6198258_2020-04-06_8FD7V68U.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6198258_2020-04-06_8FD7V68U.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6290317_2020-04-07_VOP6C1YD.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6290317_2020-04-07_VOP6C1YD.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6202009_2020-04-06_VQYHXAH9.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6202009_2020-04-06_VQYHXAH9.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6202046_2020-04-06_VQYHXAH9.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6202046_2020-04-06_VQYHXAH9.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6210093_2020-04-06_PINTW1JW.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6210093_2020-04-06_PINTW1JW.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6207651_2020-04-06_G8PUBZJZ.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6207651_2020-04-06_G8PUBZJZ.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6290313_2020-04-07_VOP6C1YD.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6290313_2020-04-07_VOP6C1YD.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6204684_2020-04-06_3A0HVH7M.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6204684_2020-04-06_3A0HVH7M.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6198253_2020-04-06_8FD7V68U.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6198253_2020-04-06_8FD7V68U.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6210084_2020-04-06_PINTW1JW.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6210084_2020-04-06_PINTW1JW.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6303004_2020-04-07_6TRPHPKK.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6303004_2020-04-07_6TRPHPKK.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6293603_2020-04-07_65Z6X809.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6293603_2020-04-07_65Z6X809.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6198280_2020-04-06_8FD7V68U.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6198280_2020-04-06_8FD7V68U.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6207673_2020-04-06_G8PUBZJZ.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6207673_2020-04-06_G8PUBZJZ.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6302963_2020-04-07_6TRPHPKK.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6302963_2020-04-07_6TRPHPKK.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6293633_2020-04-07_65Z6X809.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6293633_2020-04-07_65Z6X809.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6296556_2020-04-07_AN4ET85U.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6296556_2020-04-07_AN4ET85U.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6204721_2020-04-06_3A0HVH7M.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6204721_2020-04-06_3A0HVH7M.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6207632_2020-04-06_G8PUBZJZ.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6207632_2020-04-06_G8PUBZJZ.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6202003_2020-04-06_VQYHXAH9.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6202003_2020-04-06_VQYHXAH9.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6207665_2020-04-06_G8PUBZJZ.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6207665_2020-04-06_G8PUBZJZ.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6207654_2020-04-06_G8PUBZJZ.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6207654_2020-04-06_G8PUBZJZ.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6210063_2020-04-06_PINTW1JW.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6210063_2020-04-06_PINTW1JW.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6207635_2020-04-06_G8PUBZJZ.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6207635_2020-04-06_G8PUBZJZ.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6210073_2020-04-06_PINTW1JW.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6210073_2020-04-06_PINTW1JW.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6207644_2020-04-06_G8PUBZJZ.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6207644_2020-04-06_G8PUBZJZ.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6202004_2020-04-06_VQYHXAH9.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6202004_2020-04-06_VQYHXAH9.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6296542_2020-04-07_AN4ET85U.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6296542_2020-04-07_AN4ET85U.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6204704_2020-04-06_3A0HVH7M.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6204704_2020-04-06_3A0HVH7M.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6204713_2020-04-06_3A0HVH7M.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6204713_2020-04-06_3A0HVH7M.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6198273_2020-04-06_8FD7V68U.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6198273_2020-04-06_8FD7V68U.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6204722_2020-04-06_3A0HVH7M.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6204722_2020-04-06_3A0HVH7M.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6210064_2020-04-06_PINTW1JW.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6210064_2020-04-06_PINTW1JW.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6290311_2020-04-07_VOP6C1YD.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6290311_2020-04-07_VOP6C1YD.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6204689_2020-04-06_3A0HVH7M.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6204689_2020-04-06_3A0HVH7M.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6299909_2020-04-07_97E1HH8L.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6299909_2020-04-07_97E1HH8L.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6293601_2020-04-07_65Z6X809.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6293601_2020-04-07_65Z6X809.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6210093_2020-04-06_PINTW1JW.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6210093_2020-04-06_PINTW1JW.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6202046_2020-04-06_VQYHXAH9.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6202046_2020-04-06_VQYHXAH9.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6202009_2020-04-06_VQYHXAH9.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6202009_2020-04-06_VQYHXAH9.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6198258_2020-04-06_8FD7V68U.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6198258_2020-04-06_8FD7V68U.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6290317_2020-04-07_VOP6C1YD.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6290317_2020-04-07_VOP6C1YD.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6299900_2020-04-07_97E1HH8L.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6299900_2020-04-07_97E1HH8L.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6299889_2020-04-07_97E1HH8L.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6299889_2020-04-07_97E1HH8L.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6207655_2020-04-06_G8PUBZJZ.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6207655_2020-04-06_G8PUBZJZ.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6296562_2020-04-07_AN4ET85U.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6296562_2020-04-07_AN4ET85U.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6198284_2020-04-06_8FD7V68U.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6198284_2020-04-06_8FD7V68U.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6302999_2020-04-07_6TRPHPKK.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6302999_2020-04-07_6TRPHPKK.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6302963_2020-04-07_6TRPHPKK.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6302963_2020-04-07_6TRPHPKK.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6207673_2020-04-06_G8PUBZJZ.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6207673_2020-04-06_G8PUBZJZ.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6198280_2020-04-06_8FD7V68U.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6198280_2020-04-06_8FD7V68U.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6293603_2020-04-07_65Z6X809.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6293603_2020-04-07_65Z6X809.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6210084_2020-04-06_PINTW1JW.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6210084_2020-04-06_PINTW1JW.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6198253_2020-04-06_8FD7V68U.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6198253_2020-04-06_8FD7V68U.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6303004_2020-04-07_6TRPHPKK.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6303004_2020-04-07_6TRPHPKK.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6204684_2020-04-06_3A0HVH7M.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6204684_2020-04-06_3A0HVH7M.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6290313_2020-04-07_VOP6C1YD.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6290313_2020-04-07_VOP6C1YD.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6207651_2020-04-06_G8PUBZJZ.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6207651_2020-04-06_G8PUBZJZ.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6299881_2020-04-07_97E1HH8L.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6299881_2020-04-07_97E1HH8L.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6204701_2020-04-06_3A0HVH7M.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6204701_2020-04-06_3A0HVH7M.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6210088_2020-04-06_PINTW1JW.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6210088_2020-04-06_PINTW1JW.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6293631_2020-04-07_65Z6X809.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6293631_2020-04-07_65Z6X809.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6302982_2020-04-07_6TRPHPKK.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6302982_2020-04-07_6TRPHPKK.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6290332_2020-04-07_VOP6C1YD.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6290332_2020-04-07_VOP6C1YD.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6202030_2020-04-06_VQYHXAH9.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6202030_2020-04-06_VQYHXAH9.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6210079_2020-04-06_PINTW1JW.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6210079_2020-04-06_PINTW1JW.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6204676_2020-04-06_3A0HVH7M.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6204676_2020-04-06_3A0HVH7M.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6296561_2020-04-07_AN4ET85U.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6296561_2020-04-07_AN4ET85U.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6198288_2020-04-06_8FD7V68U.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6198288_2020-04-06_8FD7V68U.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6202028_2020-04-06_VQYHXAH9.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6202028_2020-04-06_VQYHXAH9.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6210050_2020-04-06_PINTW1JW.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6210050_2020-04-06_PINTW1JW.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6202034_2020-04-06_VQYHXAH9.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6202034_2020-04-06_VQYHXAH9.png
#   inflating: biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6198276_2020-04-06_8FD7V68U.png
#   inflating: __MACOSX/biased_cars_3/RED_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6198276_2020-04-06_8FD7V68U.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/test/images/frame_0005_0_5_6969904_2020-08-09_BB6Y5I5Y.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/test/images/._frame_0005_0_5_6969904_2020-08-09_BB6Y5I5Y.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/test/images/frame_0005_0_5_6970445_2020-08-09_RK5577CS.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/test/images/._frame_0005_0_5_6970445_2020-08-09_RK5577CS.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/test/images/frame_0005_0_5_6970991_2020-08-09_RPG3YGQW.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/test/images/._frame_0005_0_5_6970991_2020-08-09_RPG3YGQW.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/test/images/frame_0005_0_5_6969371_2020-08-09_DV62YORH.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/test/images/._frame_0005_0_5_6969371_2020-08-09_DV62YORH.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/test/images/frame_0005_0_5_6968841_2020-08-09_3OONGIOU.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/test/images/._frame_0005_0_5_6968841_2020-08-09_3OONGIOU.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/test/labels/label_frame_0005_0_5_6970445_2020-08-09_RK5577CS.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/test/labels/._label_frame_0005_0_5_6970445_2020-08-09_RK5577CS.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/test/labels/label_frame_0005_0_5_6969904_2020-08-09_BB6Y5I5Y.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/test/labels/._label_frame_0005_0_5_6969904_2020-08-09_BB6Y5I5Y.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/test/labels/label_frame_0005_0_5_6970991_2020-08-09_RPG3YGQW.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/test/labels/._label_frame_0005_0_5_6970991_2020-08-09_RPG3YGQW.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/test/labels/label_frame_0005_0_5_6968841_2020-08-09_3OONGIOU.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/test/labels/._label_frame_0005_0_5_6968841_2020-08-09_3OONGIOU.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/test/labels/label_frame_0005_0_5_6969371_2020-08-09_DV62YORH.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/test/labels/._label_frame_0005_0_5_6969371_2020-08-09_DV62YORH.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6968836_2020-08-09_3OONGIOU.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6968836_2020-08-09_3OONGIOU.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6969378_2020-08-09_DV62YORH.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6969378_2020-08-09_DV62YORH.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6969908_2020-08-09_BB6Y5I5Y.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6969908_2020-08-09_BB6Y5I5Y.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6969936_2020-08-09_BB6Y5I5Y.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6969936_2020-08-09_BB6Y5I5Y.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6969947_2020-08-09_BB6Y5I5Y.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6969947_2020-08-09_BB6Y5I5Y.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6968843_2020-08-09_3OONGIOU.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6968843_2020-08-09_3OONGIOU.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6969943_2020-08-09_BB6Y5I5Y.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6969943_2020-08-09_BB6Y5I5Y.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6968861_2020-08-09_3OONGIOU.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6968861_2020-08-09_3OONGIOU.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6970441_2020-08-09_RK5577CS.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6970441_2020-08-09_RK5577CS.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6970430_2020-08-09_RK5577CS.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6970430_2020-08-09_RK5577CS.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6969370_2020-08-09_DV62YORH.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6969370_2020-08-09_DV62YORH.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6970990_2020-08-09_RPG3YGQW.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6970990_2020-08-09_RPG3YGQW.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6968818_2020-08-09_3OONGIOU.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6968818_2020-08-09_3OONGIOU.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6969359_2020-08-09_DV62YORH.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6969359_2020-08-09_DV62YORH.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6970961_2020-08-09_RPG3YGQW.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6970961_2020-08-09_RPG3YGQW.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6969374_2020-08-09_DV62YORH.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6969374_2020-08-09_DV62YORH.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6969902_2020-08-09_BB6Y5I5Y.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6969902_2020-08-09_BB6Y5I5Y.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6971000_2020-08-09_RPG3YGQW.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6971000_2020-08-09_RPG3YGQW.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6970974_2020-08-09_RPG3YGQW.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6970974_2020-08-09_RPG3YGQW.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6969920_2020-08-09_BB6Y5I5Y.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6969920_2020-08-09_BB6Y5I5Y.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6970968_2020-08-09_RPG3YGQW.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6970968_2020-08-09_RPG3YGQW.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6970454_2020-08-09_RK5577CS.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6970454_2020-08-09_RK5577CS.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6970992_2020-08-09_RPG3YGQW.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6970992_2020-08-09_RPG3YGQW.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6968849_2020-08-09_3OONGIOU.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6968849_2020-08-09_3OONGIOU.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6970448_2020-08-09_RK5577CS.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6970448_2020-08-09_RK5577CS.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6969376_2020-08-09_DV62YORH.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6969376_2020-08-09_DV62YORH.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6969375_2020-08-09_DV62YORH.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6969375_2020-08-09_DV62YORH.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6968845_2020-08-09_3OONGIOU.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6968845_2020-08-09_3OONGIOU.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6970417_2020-08-09_RK5577CS.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6970417_2020-08-09_RK5577CS.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6969923_2020-08-09_BB6Y5I5Y.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6969923_2020-08-09_BB6Y5I5Y.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6970440_2020-08-09_RK5577CS.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6970440_2020-08-09_RK5577CS.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6969380_2020-08-09_DV62YORH.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6969380_2020-08-09_DV62YORH.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6970453_2020-08-09_RK5577CS.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6970453_2020-08-09_RK5577CS.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6971003_2020-08-09_RPG3YGQW.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6971003_2020-08-09_RPG3YGQW.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/frame_0005_0_5_6968823_2020-08-09_3OONGIOU.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/images/._frame_0005_0_5_6968823_2020-08-09_3OONGIOU.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6970430_2020-08-09_RK5577CS.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6970430_2020-08-09_RK5577CS.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6969370_2020-08-09_DV62YORH.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6969370_2020-08-09_DV62YORH.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6970441_2020-08-09_RK5577CS.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6970441_2020-08-09_RK5577CS.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6969374_2020-08-09_DV62YORH.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6969374_2020-08-09_DV62YORH.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6970961_2020-08-09_RPG3YGQW.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6970961_2020-08-09_RPG3YGQW.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6968818_2020-08-09_3OONGIOU.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6968818_2020-08-09_3OONGIOU.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6969359_2020-08-09_DV62YORH.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6969359_2020-08-09_DV62YORH.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6970990_2020-08-09_RPG3YGQW.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6970990_2020-08-09_RPG3YGQW.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6969947_2020-08-09_BB6Y5I5Y.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6969947_2020-08-09_BB6Y5I5Y.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6969908_2020-08-09_BB6Y5I5Y.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6969908_2020-08-09_BB6Y5I5Y.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6969936_2020-08-09_BB6Y5I5Y.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6969936_2020-08-09_BB6Y5I5Y.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6969378_2020-08-09_DV62YORH.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6969378_2020-08-09_DV62YORH.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6968836_2020-08-09_3OONGIOU.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6968836_2020-08-09_3OONGIOU.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6968861_2020-08-09_3OONGIOU.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6968861_2020-08-09_3OONGIOU.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6969943_2020-08-09_BB6Y5I5Y.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6969943_2020-08-09_BB6Y5I5Y.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6968843_2020-08-09_3OONGIOU.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6968843_2020-08-09_3OONGIOU.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6970417_2020-08-09_RK5577CS.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6970417_2020-08-09_RK5577CS.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6968845_2020-08-09_3OONGIOU.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6968845_2020-08-09_3OONGIOU.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6969375_2020-08-09_DV62YORH.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6969375_2020-08-09_DV62YORH.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6968823_2020-08-09_3OONGIOU.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6968823_2020-08-09_3OONGIOU.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6970453_2020-08-09_RK5577CS.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6970453_2020-08-09_RK5577CS.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6971003_2020-08-09_RPG3YGQW.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6971003_2020-08-09_RPG3YGQW.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6969380_2020-08-09_DV62YORH.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6969380_2020-08-09_DV62YORH.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6970440_2020-08-09_RK5577CS.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6970440_2020-08-09_RK5577CS.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6969923_2020-08-09_BB6Y5I5Y.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6969923_2020-08-09_BB6Y5I5Y.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6970968_2020-08-09_RPG3YGQW.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6970968_2020-08-09_RPG3YGQW.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6969920_2020-08-09_BB6Y5I5Y.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6969920_2020-08-09_BB6Y5I5Y.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6970974_2020-08-09_RPG3YGQW.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6970974_2020-08-09_RPG3YGQW.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6971000_2020-08-09_RPG3YGQW.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6971000_2020-08-09_RPG3YGQW.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6969902_2020-08-09_BB6Y5I5Y.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6969902_2020-08-09_BB6Y5I5Y.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6969376_2020-08-09_DV62YORH.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6969376_2020-08-09_DV62YORH.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6968849_2020-08-09_3OONGIOU.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6968849_2020-08-09_3OONGIOU.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6970448_2020-08-09_RK5577CS.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6970448_2020-08-09_RK5577CS.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6970992_2020-08-09_RPG3YGQW.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6970992_2020-08-09_RPG3YGQW.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/label_frame_0005_0_5_6970454_2020-08-09_RK5577CS.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/train/labels/._label_frame_0005_0_5_6970454_2020-08-09_RK5577CS.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6968839_2020-08-09_3OONGIOU.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6968839_2020-08-09_3OONGIOU.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6970993_2020-08-09_RPG3YGQW.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6970993_2020-08-09_RPG3YGQW.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6969364_2020-08-09_DV62YORH.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6969364_2020-08-09_DV62YORH.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6971001_2020-08-09_RPG3YGQW.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6971001_2020-08-09_RPG3YGQW.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6970412_2020-08-09_RK5577CS.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6970412_2020-08-09_RK5577CS.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6969367_2020-08-09_DV62YORH.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6969367_2020-08-09_DV62YORH.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6969918_2020-08-09_BB6Y5I5Y.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6969918_2020-08-09_BB6Y5I5Y.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6969942_2020-08-09_BB6Y5I5Y.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6969942_2020-08-09_BB6Y5I5Y.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6970432_2020-08-09_RK5577CS.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6970432_2020-08-09_RK5577CS.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6968824_2020-08-09_3OONGIOU.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6968824_2020-08-09_3OONGIOU.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6970412_2020-08-09_RK5577CS.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6970412_2020-08-09_RK5577CS.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6969918_2020-08-09_BB6Y5I5Y.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6969918_2020-08-09_BB6Y5I5Y.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6969367_2020-08-09_DV62YORH.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6969367_2020-08-09_DV62YORH.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6969364_2020-08-09_DV62YORH.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6969364_2020-08-09_DV62YORH.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6970993_2020-08-09_RPG3YGQW.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6970993_2020-08-09_RPG3YGQW.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6968839_2020-08-09_3OONGIOU.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6968839_2020-08-09_3OONGIOU.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6971001_2020-08-09_RPG3YGQW.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6971001_2020-08-09_RPG3YGQW.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6970432_2020-08-09_RK5577CS.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6970432_2020-08-09_RK5577CS.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6969942_2020-08-09_BB6Y5I5Y.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6969942_2020-08-09_BB6Y5I5Y.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6968824_2020-08-09_3OONGIOU.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6968824_2020-08-09_3OONGIOU.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_1_ROTATION_OLD/test/images/frame_0005_0_5_7046087_2020-08-10_N73OT1XR.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_1_ROTATION_OLD/test/images/._frame_0005_0_5_7046087_2020-08-10_N73OT1XR.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_1_ROTATION_OLD/test/images/frame_0005_0_5_7047021_2020-08-10_NLK8IPKS.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_1_ROTATION_OLD/test/images/._frame_0005_0_5_7047021_2020-08-10_NLK8IPKS.png
#   inflating: biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_1_ROTATION_OLD/test/images/frame_0005_0_5_7047787_2020-08-10_GH6V8BR6.png
#   inflating: __MACOSX/biased_cars_3/REBUTTAL_BLACK_CARS_9_SCALE_1_ROTATION_OLD/test/images/._frame_0005_0_5_7047787_2020-08-10_GH6V8BR6.png
# ...
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6293482_2020-04-07_PPHOCPUY.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6293482_2020-04-07_PPHOCPUY.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6290408_2020-04-07_4RPLVIRE.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6290408_2020-04-07_4RPLVIRE.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6204426_2020-04-06_NSTG2NS1.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6204426_2020-04-06_NSTG2NS1.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6298506_2020-04-07_SD5D600L.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6298506_2020-04-07_SD5D600L.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6204418_2020-04-06_NSTG2NS1.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6204418_2020-04-06_NSTG2NS1.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/images/frame_0005_0_5_6198666_2020-04-06_B2W54TIL.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/images/._frame_0005_0_5_6198666_2020-04-06_B2W54TIL.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6296460_2020-04-07_9FXXLUHP.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6296460_2020-04-07_9FXXLUHP.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6198674_2020-04-06_B2W54TIL.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6198674_2020-04-06_B2W54TIL.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6208738_2020-04-06_WDUV5857.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6208738_2020-04-06_WDUV5857.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6206916_2020-04-06_V66P552Y.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6206916_2020-04-06_V66P552Y.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6296433_2020-04-07_9FXXLUHP.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6296433_2020-04-07_9FXXLUHP.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6198685_2020-04-06_B2W54TIL.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6198685_2020-04-06_B2W54TIL.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6201820_2020-04-06_TUE1L46O.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6201820_2020-04-06_TUE1L46O.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6201806_2020-04-06_TUE1L46O.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6201806_2020-04-06_TUE1L46O.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6208702_2020-04-06_WDUV5857.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6208702_2020-04-06_WDUV5857.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6298467_2020-04-07_SD5D600L.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6298467_2020-04-07_SD5D600L.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6198681_2020-04-06_B2W54TIL.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6198681_2020-04-06_B2W54TIL.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6208723_2020-04-06_WDUV5857.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6208723_2020-04-06_WDUV5857.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6298489_2020-04-07_SD5D600L.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6298489_2020-04-07_SD5D600L.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6293435_2020-04-07_PPHOCPUY.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6293435_2020-04-07_PPHOCPUY.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6298477_2020-04-07_SD5D600L.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6298477_2020-04-07_SD5D600L.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6296459_2020-04-07_9FXXLUHP.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6296459_2020-04-07_9FXXLUHP.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6301545_2020-04-07_PZNS375X.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6301545_2020-04-07_PZNS375X.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6206949_2020-04-06_V66P552Y.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6206949_2020-04-06_V66P552Y.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6206937_2020-04-06_V66P552Y.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6206937_2020-04-06_V66P552Y.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6201796_2020-04-06_TUE1L46O.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6201796_2020-04-06_TUE1L46O.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6301581_2020-04-07_PZNS375X.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6301581_2020-04-07_PZNS375X.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6293471_2020-04-07_PPHOCPUY.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6293471_2020-04-07_PPHOCPUY.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6204437_2020-04-06_NSTG2NS1.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6204437_2020-04-06_NSTG2NS1.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6208734_2020-04-06_WDUV5857.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6208734_2020-04-06_WDUV5857.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6201785_2020-04-06_TUE1L46O.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6201785_2020-04-06_TUE1L46O.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6290365_2020-04-07_4RPLVIRE.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6290365_2020-04-07_4RPLVIRE.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6301536_2020-04-07_PZNS375X.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6301536_2020-04-07_PZNS375X.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6198666_2020-04-06_B2W54TIL.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6198666_2020-04-06_B2W54TIL.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6298506_2020-04-07_SD5D600L.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6298506_2020-04-07_SD5D600L.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6204426_2020-04-06_NSTG2NS1.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6204426_2020-04-06_NSTG2NS1.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6204418_2020-04-06_NSTG2NS1.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6204418_2020-04-06_NSTG2NS1.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6290408_2020-04-07_4RPLVIRE.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6290408_2020-04-07_4RPLVIRE.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6198669_2020-04-06_B2W54TIL.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6198669_2020-04-06_B2W54TIL.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6293482_2020-04-07_PPHOCPUY.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6293482_2020-04-07_PPHOCPUY.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6198697_2020-04-06_B2W54TIL.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6198697_2020-04-06_B2W54TIL.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6208708_2020-04-06_WDUV5857.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6208708_2020-04-06_WDUV5857.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6206926_2020-04-06_V66P552Y.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6206926_2020-04-06_V66P552Y.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6201787_2020-04-06_TUE1L46O.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6201787_2020-04-06_TUE1L46O.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6208736_2020-04-06_WDUV5857.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6208736_2020-04-06_WDUV5857.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6290390_2020-04-07_4RPLVIRE.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6290390_2020-04-07_4RPLVIRE.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6204448_2020-04-06_NSTG2NS1.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6204448_2020-04-06_NSTG2NS1.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6204439_2020-04-06_NSTG2NS1.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6204439_2020-04-06_NSTG2NS1.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6201800_2020-04-06_TUE1L46O.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6201800_2020-04-06_TUE1L46O.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6290371_2020-04-07_4RPLVIRE.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6290371_2020-04-07_4RPLVIRE.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6206914_2020-04-06_V66P552Y.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6206914_2020-04-06_V66P552Y.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6296462_2020-04-07_9FXXLUHP.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6296462_2020-04-07_9FXXLUHP.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6208744_2020-04-06_WDUV5857.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6208744_2020-04-06_WDUV5857.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6204454_2020-04-06_NSTG2NS1.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6204454_2020-04-06_NSTG2NS1.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6301553_2020-04-07_PZNS375X.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6301553_2020-04-07_PZNS375X.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6208718_2020-04-06_WDUV5857.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6208718_2020-04-06_WDUV5857.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6201813_2020-04-06_TUE1L46O.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6201813_2020-04-06_TUE1L46O.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6198654_2020-04-06_B2W54TIL.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6198654_2020-04-06_B2W54TIL.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6206948_2020-04-06_V66P552Y.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6206948_2020-04-06_V66P552Y.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6206903_2020-04-06_V66P552Y.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6206903_2020-04-06_V66P552Y.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6293468_2020-04-07_PPHOCPUY.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6293468_2020-04-07_PPHOCPUY.png
#   inflating: biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/label_frame_0005_0_5_6206932_2020-04-06_V66P552Y.png
#   inflating: __MACOSX/biased_cars_4/BLACK_CARS_9_SCALE_4_ROTATION/val/labels/._label_frame_0005_0_5_6206932_2020-04-06_V66P552Y.png
# moving files to correct directories...
# Removing unwanted files...
# All done!

# %%
# CODE_ROOT = '..'

# %%
from __future__ import print_function, division
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import copy
import os
from PIL import ImageFile
import random
ImageFile.LOAD_TRUNCATED_IMAGES = True
import argparse
import pickle
import sys
sys.path.append('%s/res/'%CODE_ROOT)
from models.models import get_model
from loader.loader import get_loader
from tqdm.notebook import tqdm
from IPython.display import clear_output
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context("poster")
sns.set_palette("Set1", 8, .75)
sns.despine()
# Out:
# /content
# generalization_to_OOD_category_viewpoint_combinations//res/loader/loader.py
# generalization_to_OOD_category_viewpoint_combinations//res/loader

# %%
torch.cuda.get_device_name(0)
# Out:
# 'Tesla P100-PCIE-16GB'

# %%
image_url = "../docs/images/biased_cars_samples.gif"
Image(url=image_url, width=500)
# Out:
# <img src="../docs/images/biased_cars_samples.gif" width="500"/>

# %%
DATASET_NAMES = ['rotation_model_5_compositions_seen','rotation_model_10_compositions_seen',
                 'rotation_model_15_compositions_seen','rotation_model_20_compositions_seen']

NUM_EPOCHS =2
BATCH_SIZE = 2
image_transform=transforms.Compose([
        transforms.Resize([28, 28]),
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))
    ])


GPU = 1

# %%
NUM_CLASSES = (5,5,5,5)
loader_new = get_loader('multi_attribute_loader_file_list')

file_list_root = '%s/dataset_lists/biased_cars_lists/'%CODE_ROOT
att_path = "%s/data/biased_cars/att_dict_simplified.p"%CODE_ROOT

# %%
shuffles = {'train':True,'val':True,'test':False}

# %%
data_dir = '%s/data/'%CODE_ROOT

# %%
all_dsets = {}
all_dset_loaders = {}
all_dset_sizes = {}

for DATASET_NAME in DATASET_NAMES:
    file_lists = {}
    dsets = {}
    dset_loaders = {}
    dset_sizes = {}
    for phase in ['train','val','test']:
        file_lists[phase] = "%s/%s_list_%s.txt"%(file_list_root,phase,DATASET_NAME)
        dsets[phase] = loader_new(file_lists[phase],att_path, image_transform, data_dir)
        dset_loaders[phase] = torch.utils.data.DataLoader(dsets[phase], batch_size=BATCH_SIZE, shuffle = shuffles[phase], num_workers=2,drop_last=True)
        dset_sizes[phase] = len(dsets[phase])
    all_dsets[DATASET_NAME] = dsets
    all_dset_loaders[DATASET_NAME] = dset_loaders
    all_dset_sizes[DATASET_NAME] = dset_sizes

# %%
all_dsets
# Out:
# {'rotation_model_10_compositions_seen': {'test': Dataset FileListFolder
#       Number of datapoints: 800
#       Root Location: generalization_to_OOD_category_viewpoint_combinations//dataset_lists/biased_cars_lists//test_list_rotation_model_10_compositions_seen.txt
#       Transforms (if any): Compose(
#                                Resize(size=[28, 28], interpolation=bilinear, max_size=None, antialias=None)
#                                ToTensor()
#                                Normalize(mean=(0.1307,), std=(0.3081,))
#                            ), 'train': Dataset FileListFolder
#       Number of datapoints: 3400
#       Root Location: generalization_to_OOD_category_viewpoint_combinations//dataset_lists/biased_cars_lists//train_list_rotation_model_10_compositions_seen.txt
#       Transforms (if any): Compose(
#                                Resize(size=[28, 28], interpolation=bilinear, max_size=None, antialias=None)
#                                ToTensor()
#                                Normalize(mean=(0.1307,), std=(0.3081,))
#                            ), 'val': Dataset FileListFolder
#       Number of datapoints: 445
#       Root Location: generalization_to_OOD_category_viewpoint_combinations//dataset_lists/biased_cars_lists//val_list_rotation_model_10_compositions_seen.txt
#       Transforms (if any): Compose(
#                                Resize(size=[28, 28], interpolation=bilinear, max_size=None, antialias=None)
#                                ToTensor()
#                                Normalize(mean=(0.1307,), std=(0.3081,))
#                            )},
#  'rotation_model_15_compositions_seen': {'test': Dataset FileListFolder
#       Number of datapoints: 800
#       Root Location: generalization_to_OOD_category_viewpoint_combinations//dataset_lists/biased_cars_lists//test_list_rotation_model_15_compositions_seen.txt
#       Transforms (if any): Compose(
#                                Resize(size=[28, 28], interpolation=bilinear, max_size=None, antialias=None)
#                                ToTensor()
#                                Normalize(mean=(0.1307,), std=(0.3081,))
#                            ), 'train': Dataset FileListFolder
#       Number of datapoints: 3400
#       Root Location: generalization_to_OOD_category_viewpoint_combinations//dataset_lists/biased_cars_lists//train_list_rotation_model_15_compositions_seen.txt
#       Transforms (if any): Compose(
#                                Resize(size=[28, 28], interpolation=bilinear, max_size=None, antialias=None)
#                                ToTensor()
#                                Normalize(mean=(0.1307,), std=(0.3081,))
#                            ), 'val': Dataset FileListFolder
#       Number of datapoints: 445
#       Root Location: generalization_to_OOD_category_viewpoint_combinations//dataset_lists/biased_cars_lists//val_list_rotation_model_15_compositions_seen.txt
#       Transforms (if any): Compose(
#                                Resize(size=[28, 28], interpolation=bilinear, max_size=None, antialias=None)
#                                ToTensor()
#                                Normalize(mean=(0.1307,), std=(0.3081,))
#                            )},
#  'rotation_model_20_compositions_seen': {'test': Dataset FileListFolder
#       Number of datapoints: 800
#       Root Location: generalization_to_OOD_category_viewpoint_combinations//dataset_lists/biased_cars_lists//test_list_rotation_model_20_compositions_seen.txt
#       Transforms (if any): Compose(
#                                Resize(size=[28, 28], interpolation=bilinear, max_size=None, antialias=None)
#                                ToTensor()
#                                Normalize(mean=(0.1307,), std=(0.3081,))
#                            ), 'train': Dataset FileListFolder
#       Number of datapoints: 3400
#       Root Location: generalization_to_OOD_category_viewpoint_combinations//dataset_lists/biased_cars_lists//train_list_rotation_model_20_compositions_seen.txt
#       Transforms (if any): Compose(
#                                Resize(size=[28, 28], interpolation=bilinear, max_size=None, antialias=None)
#                                ToTensor()
#                                Normalize(mean=(0.1307,), std=(0.3081,))
#                            ), 'val': Dataset FileListFolder
#       Number of datapoints: 445
#       Root Location: generalization_to_OOD_category_viewpoint_combinations//dataset_lists/biased_cars_lists//val_list_rotation_model_20_compositions_seen.txt
#       Transforms (if any): Compose(
#                                Resize(size=[28, 28], interpolation=bilinear, max_size=None, antialias=None)
#                                ToTensor()
#                                Normalize(mean=(0.1307,), std=(0.3081,))
#                            )},
#  'rotation_model_5_compositions_seen': {'test': Dataset FileListFolder
#       Number of datapoints: 800
#       Root Location: generalization_to_OOD_category_viewpoint_combinations//dataset_lists/biased_cars_lists//test_list_rotation_model_5_compositions_seen.txt
#       Transforms (if any): Compose(
#                                Resize(size=[28, 28], interpolation=bilinear, max_size=None, antialias=None)
#                                ToTensor()
#                                Normalize(mean=(0.1307,), std=(0.3081,))
#                            ), 'train': Dataset FileListFolder
#       Number of datapoints: 3400
#       Root Location: generalization_to_OOD_category_viewpoint_combinations//dataset_lists/biased_cars_lists//train_list_rotation_model_5_compositions_seen.txt
#       Transforms (if any): Compose(
#                                Resize(size=[28, 28], interpolation=bilinear, max_size=None, antialias=None)
#                                ToTensor()
#                                Normalize(mean=(0.1307,), std=(0.3081,))
#                            ), 'val': Dataset FileListFolder
#       Number of datapoints: 445
#       Root Location: generalization_to_OOD_category_viewpoint_combinations//dataset_lists/biased_cars_lists//val_list_rotation_model_5_compositions_seen.txt
#       Transforms (if any): Compose(
#                                Resize(size=[28, 28], interpolation=bilinear, max_size=None, antialias=None)
#                                ToTensor()
#                                Normalize(mean=(0.1307,), std=(0.3081,))
#                            )}}

# %%
class sgan_Generator(nn.Module):
    def __init__(self, n_classes, latent_dim, image_size):
        super(Generator, self).__init__()
        self.n_classes = n_classes
        self.latent_dim = latent_dim
        self.image_size = image_size

        self.label_emb = nn.Embedding(self.n_classes, self.latent_dim)

        self.init_size = self.image_size // 4 
        self.l1 = nn.Sequential(nn.Linear(self.latent_dim, 128 * self.init_size ** 2))

        self.conv_blocks = nn.Sequential(
            nn.BatchNorm2d(128),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 128, 3, stride=1, padding=1),
            nn.BatchNorm2d(128, 0.8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 64, 3, stride=1, padding=1),
            nn.BatchNorm2d(64, 0.8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, 3, 3, stride=1, padding=1),
            nn.Tanh(),
        )

    def forward(self, noise, labels):
        gen_input = torch.mul(self.label_emb(labels), noise)
        out = self.l1(gen_input)
        out = out.view(out.shape[0], 128, self.init_size, self.init_size)
        img = self.conv_blocks(out)
        return img

# %%
class sgan_Discriminator(nn.Module):
    def __init__(self, n_classes, latent_dim, image_size):
        super(Discriminator, self).__init__()
        self.n_classes = n_classes
        self.latent_dim = latent_dim
        self.image_size = image_size


        def discriminator_block(in_filters, out_filters, bn=True):
            """Returns layers of each discriminator block"""
            block = [nn.Conv2d(in_filters, out_filters, 3, 2, 1), nn.LeakyReLU(0.2, inplace=True), nn.Dropout2d(0.25)]
            if bn:
                block.append(nn.BatchNorm2d(out_filters, 0.8))
            return block

        self.conv_blocks = nn.Sequential(
            *discriminator_block(opt.channels, 16, bn=False),
            *discriminator_block(16, 32),
            *discriminator_block(32, 64),
            *discriminator_block(64, 128),
        )

        # The height and width of downsampled image
        ds_size = opt.img_size // 2 ** 4

        # Output layers
        self.adv_layer = nn.Sequential(nn.Linear(128 * ds_size ** 2, 1), nn.Sigmoid())
        self.aux_layer = nn.Sequential(nn.Linear(128 * ds_size ** 2,  self.n_classes), nn.Softmax())

    def forward(self, img):
        out = self.conv_blocks(img)
        out = out.view(out.shape[0], -1)
        validity = self.adv_layer(out)
        label = self.aux_layer(out)

        return validity, label

# %%
adversarial_loss = torch.nn.BCELoss()
auxiliary_loss = torch.nn.CrossEntropyLoss()

# %%
class DCGAN_Generator(nn.Module):
    def __init__(self):
        super(DCGAN_Generator,self).__init__()
        self.gnet = nn.Sequential(
            nn.ConvTranspose2d(128, 512, 3, 1, 0),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2),
            nn.ConvTranspose2d(512, 256, 5, 2, 1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),
            nn.ConvTranspose2d(256, 128, 5, 2, 2, 1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),
            nn.ConvTranspose2d(128, 1, 5, 2, 2, 1),
            nn.Tanh()
        )


    def forward(self, input):     
        out = self.gnet(input)
        return out


class DCGAN_Discriminator(nn.Module):
    def __init__(self):
        super(DCGAN_Discriminator, self).__init__()
        self.dnet = nn.Sequential(
            nn.Conv2d(1, 128, 5, 2, 2),
            nn.LeakyReLU(0.2), 
            nn.Conv2d(128, 256, 5, 2, 2),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),
            nn.Conv2d(256, 512, 5, 2, 1), 
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2),
            nn.Conv2d(512, 1, 3, 1, 0),
            nn.Sigmoid()
        )
        
        
    
    def forward(self, input):

        bs, _, _, _ = input.shape
        out = self.dnet(input)
        out = out.reshape(bs, -1)
        return out

# %%
def loss_discriminator(D, real, G, noise, Valid_label, Fake_label, criterion, optimizerD):

    D.zero_grad()
    real_out = D(real).view(-1)
    d_real_loss = criterion(real_out,Valid_label)
    d_real_loss.backward()
    fake_imgs = G(noise)
    fake_out = D(fake_imgs.detach()).view(-1)
    d_fake_loss = criterion(fake_out, Fake_label)
    d_fake_loss.backward()
    loss_D = d_fake_loss+d_real_loss
    optimizerD.step()

    return loss_D, fake_imgs

def loss_generator(netD, netG, fake, Valid_label, criterion, optimizerG):
    
    netG.zero_grad()
    fake_out = netD(fake).view(-1)
    loss_G = criterion(fake_out, Valid_label)
    loss_G.backward()
    optimizerG.step()
   
    return loss_G

# %%
import torchvision.utils as vutils
from torch.optim.lr_scheduler import StepLR
import pdb

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

nc = 3
nz = 128

# netG = DCGAN_Generator().to(device)
# netD = DCGAN_Discriminator().to(device)

# %%
multi_losses = [nn.CrossEntropyLoss(),nn.CrossEntropyLoss(),nn.CrossEntropyLoss(),nn.CrossEntropyLoss()]

# %%
ARCHS = ['acgan','wgan','sgan']

# %%
import torchvision.utils as vutils
from torch.optim.lr_scheduler import StepLR
import pdb
def train_gan(gan_train_loader, DCGAN_Generator, DCGAN_Discriminator):

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    nc = 3
    nz = 128

    # Create the generator and discriminator
    # netG = DCGAN_Generator().to(device)
    # netD = DCGAN_Discriminator().to(device)

    # Initialize BCELoss function
    criterion = nn.BCELoss()
    # criterion = nn.BCEWithLogitsLoss()

    # Create latent vector to test the generator performance
    # fixed_noise = torch.randn(36, nz, 1, 1, device=device)

    # Establish convention for real and fake labels during training
    real_label = 1
    fake_label = 0

    learning_rate = 0.0001
    beta1 = 0.5



    optimizerD = optim.Adam(netD.parameters(), lr=learning_rate, betas=(beta1, 0.999))
    optimizerG = optim.Adam(netG.parameters(), lr=learning_rate, betas=(beta1, 0.999))




    img_list = []
    real_img_list = []
    G_losses = []
    D_losses = []
    iters = 0
    num_epochs = 15


    def load_param(num_eps):
      model_saved = torch.load('/content/gan_{}.pt'.format(num_eps))
      netG.load_state_dict(model_saved['netG'])
      netD.load_state_dict(model_saved['netD'])

    # GAN Training Loop
    for epoch in range(num_epochs):
        for i, data in enumerate(gan_train_loader, 0):
            real = data[0].to(device)
            b_size = real.size(0)
            noise = torch.randn(b_size, nz, 1, 1, device=device)

            # Valid_label = torch.full((b_size,), real_label, dtype=torch.float, device=device)
            # Fake_label = torch.full((b_size,), fake_label, dtype=torch.float, device=device)

            loss_D, fake_imgs = loss_discriminator(netD, real, netG, noise, Valid_label, Fake_label, criterion, optimizerD)
           
            loss_G = loss_generator(netD, netG, fake_imgs, Valid_label, criterion, optimizerG)

            if i % 50 == 0:
                print('[%d/%d][%d/%d]\tLoss_D: %.4f\tLoss_G: %.4f\t'
                      % (epoch, num_epochs, i, len(gan_train_loader),
                         loss_D.item(), loss_G.item()))

            G_losses.append(loss_G.item())
            D_losses.append(loss_D.item())

            if (iters % 500 == 0) or ((epoch == num_epochs-1) and (i == len(gan_train_loader)-1)):
                with torch.no_grad():
                    fake = netG(fixed_noise).detach().cpu()
                img_list.append(vutils.make_grid(fake, padding=2, normalize=True))

            iters += 1



    plt.title("Generator and Discriminator Loss During Training")
    plt.plot(G_losses,label="G")
    plt.plot(D_losses,label="D")
    plt.xlabel("iterations")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()


    checkpoint = {'netG': netG.state_dict(),
                  'netD': netD.state_dict()}
    torch.save(checkpoint, 'gan_{}.pt'.format(num_epochs))

# %%
def weight_scheduler(epoch_num, task):
    if task == 'shared':
        return [0.0,1.0,0.0,1.0]
    elif task == 'viewpoint':
        return [0.0,1.0,0.0,0.0]
    elif task == 'category':
        return [0.0,0.0,0.0,1.0]

# %%
def train_epoch(dset_loaders, dset_sizes, model, task, optimizer):
    model.train()
    torch.set_grad_enabled(True)
    phase = 'train'
    
    weights = weight_scheduler(epoch, task)
    iters = 0
    phase_epoch_corrects = [0,0,0,0]
    phase_epoch_loss = 0
    
    for data in dset_loaders[phase]:
        inputs, labels_all, paths = data
        inputs = Variable(inputs.float().cuda())

        optimizer.zero_grad()
        model_outs = model(inputs)
        calculated_loss = 0
        batch_corrects = [0,0,0,0]
        
        for i in range(4):
            labels = labels_all[:,i]
            if GPU:
                labels = Variable(labels.long().cuda())
            loss = multi_losses[i]
            outputs = model_outs[i]
            calculated_loss += weights[i] * loss(outputs,labels)
            _, preds = torch.max(outputs.data, 1)
            batch_corrects[i] = torch.sum(preds == labels.data)
            phase_epoch_corrects[i] += batch_corrects[i]

        
        phase_epoch_loss += calculated_loss
        calculated_loss.backward()
        optimizer.step()
        iters += 1
    epoch_loss = phase_epoch_loss/dset_sizes[phase]
    # print('Train loss:%s'%epoch_loss)
    epoch_accs = [float(i)/dset_sizes[phase] for i in phase_epoch_corrects]

    if task == 'shared':
        epoch_gm = np.sqrt(epoch_accs[1] * epoch_accs[3])
    elif task == 'viewpoint':
        epoch_gm = epoch_accs[1]
    elif task == 'category':
        epoch_gm = epoch_accs[3]
    
    return model, epoch_loss, epoch_gm

# %%
def test_epoch(dset_loaders, dset_sizes, model, best_model, best_test_loss, best_test_gm, task):
    model.eval()
    torch.set_grad_enabled(False)
    phase = 'val'
    weights = weight_scheduler(epoch, task)
    iters = 0
    phase_epoch_corrects = [0,0,0,0]
    phase_epoch_loss = 0
    
    for data in dset_loaders[phase]:
        inputs, labels_all, paths = data
        inputs = Variable(inputs.float().cuda())
        model_outs = model(inputs)
        calculated_loss = 0
        batch_corrects = [0,0,0,0]
        
        for i in range(4):
            labels = labels_all[:,i]
            if GPU:
                labels = Variable(labels.long().cuda())
            loss = multi_losses[i]
            outputs = model_outs[i]
            calculated_loss += weights[i] * loss(outputs,labels)
            _, preds = torch.max(outputs.data, 1)
            batch_corrects[i] = torch.sum(preds == labels.data)
            phase_epoch_corrects[i] += batch_corrects[i]


        phase_epoch_loss += calculated_loss
        iters += 1
    epoch_loss = phase_epoch_loss/dset_sizes[phase]
    # print('Test loss:%s'%epoch_loss)
    epoch_accs = [float(i)/dset_sizes[phase] for i in phase_epoch_corrects]
    
    if task == 'shared':
        epoch_gm = np.sqrt(epoch_accs[1] * epoch_accs[3])
    elif task == 'viewpoint':
        epoch_gm = epoch_accs[1]
    elif task == 'category':
        epoch_gm = epoch_accs[3]
    
    if epoch_loss < best_test_loss:
        best_model = model
        best_test_loss = epoch_loss
        best_test_gm = epoch_gm
    
    return best_model, epoch_loss, epoch_gm, best_test_loss, best_test_gm

# %%
def unseen_test_epoch(dset_loaders, dset_sizes, model, task):
    model.eval()
    torch.set_grad_enabled(False)
    phase = 'test'

    weights = weight_scheduler(epoch, task)
    iters = 0
    phase_epoch_corrects = [0,0,0,0]
    phase_epoch_loss = 0
    
    for data in dset_loaders[phase]:
        inputs, labels_all, paths = data
        inputs = Variable(inputs.float().cuda())
        model_outs = model(inputs)
        calculated_loss = 0
        batch_corrects = [0,0,0,0]
        
        for i in range(4):
            labels = labels_all[:,i]
            if GPU:
                labels = Variable(labels.long().cuda())
            loss = multi_losses[i]
            outputs = model_outs[i]
            calculated_loss += weights[i] * loss(outputs,labels)
            _, preds = torch.max(outputs.data, 1)
            batch_corrects[i] = torch.sum(preds == labels.data)
            phase_epoch_corrects[i] += batch_corrects[i]


        phase_epoch_loss += calculated_loss
        iters += 1
    epoch_loss = phase_epoch_loss/dset_sizes[phase]
    epoch_accs = [float(i)/dset_sizes[phase] for i in phase_epoch_corrects]
    
    if task == 'shared':
        epoch_gm = np.sqrt(epoch_accs[1] * epoch_accs[3])
    elif task == 'viewpoint':
        epoch_gm = epoch_accs[1]
    elif task == 'category':
        epoch_gm = epoch_accs[3]
    
    return epoch_loss, epoch_gm

# %%
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14)

# %%
DATASET_NAMES
# Out:
# ['rotation_model_5_compositions_seen',
#  'rotation_model_10_compositions_seen',
#  'rotation_model_15_compositions_seen',
#  'rotation_model_20_compositions_seen']

# %%
dataset_titles = {}
dataset_titles['rotation_model_5_compositions_seen'] = "20% combinations seen"
dataset_titles['rotation_model_10_compositions_seen'] = "40% combinations seen"
dataset_titles['rotation_model_15_compositions_seen'] = "60% combinations seen"
dataset_titles['rotation_model_20_compositions_seen'] = "80% combinations seen"

# %%
all_train_all = {}
all_test_all = {}
all_unseen_test_all = {}

# %%
for ARCH in ARCHS:
  all_train_all[ARCH + ' ' + 'shared'] = []
  all_train_all[ARCH + ' ' +'separate'] = []

  all_test_all[ARCH + ' ' +'shared'] = []
  all_test_all[ARCH + ' ' +'separate'] = []

  all_unseen_test_all[ARCH + ' ' +'shared'] = []
  all_unseen_test_all[ARCH + ' ' + 'separate'] = []

  for DATASET_NAME in DATASET_NAMES:
      print('______________________________________________________')
      print('model_name:',ARCH,'  comb_name', dataset_titles[DATASET_NAME])
      dsets = all_dsets[DATASET_NAME]
      dset_loaders = all_dset_loaders[DATASET_NAME]
      dset_sizes = all_dset_sizes[DATASET_NAME]
      
      models = {}

      models['shared']= get_model(ARCH,NUM_CLASSES)
      models['viewpoint']= get_model(ARCH,NUM_CLASSES)
      models['category']= get_model(ARCH,NUM_CLASSES)

      models['shared'].cuda();
      models['viewpoint'].cuda();
      models['category'].cuda();

      best_models = {}
      best_models['shared'] = models['shared']
      best_models['viewpoint'] = models['viewpoint']
      best_models['category'] = models['category']

      best_test_loss = 100
      best_test_gm = 0

      all_train_gms = {}
      all_train_gms['shared'] = [0]
      all_train_gms['separate'] = [0]

      all_test_gms = {}
      all_test_gms['shared'] = [0]
      all_test_gms['separate'] = [0]

      all_unseen_test_gms = {}
      all_unseen_test_gms['shared'] = [0]
      all_unseen_test_gms['separate'] = [0]

      optimizers = {}
      optimizers['shared'] = optim.Adam(models['shared'].parameters(), lr=0.001)
      optimizers['viewpoint'] = optim.Adam(models['viewpoint'].parameters(), lr=0.001)
      optimizers['category'] = optim.Adam(models['category'].parameters(), lr=0.001)
      for epoch in range(NUM_EPOCHS):
          train_gm_separate = 1
          test_gm_separate = 1
          unseen_test_gm_separate = 1

          for TASK in ['viewpoint','category','shared']:
              print('Epoch: %s, Task: %s'%(epoch,TASK))
              print('---------')
              models[TASK], train_loss, train_gm = train_epoch(dset_loaders, dset_sizes, models[TASK], TASK, optimizers[TASK])
              best_models[TASK], test_loss, test_gm, best_test_loss, best_test_gm = test_epoch(dset_loaders, dset_sizes, models[TASK], best_models[TASK], best_test_loss, best_test_gm, TASK)
              unseen_test_loss, unseen_test_gm = unseen_test_epoch(dset_loaders, dset_sizes, models[TASK], TASK)

              if TASK != 'shared':
                  train_gm_separate = train_gm_separate * train_gm
                  test_gm_separate = test_gm_separate * test_gm
                  unseen_test_gm_separate = unseen_test_gm_separate * test_gm

          all_train_gms['separate'].append(np.sqrt(train_gm_separate))
          all_test_gms['separate'].append(np.sqrt(test_gm_separate))
          all_unseen_test_gms['separate'].append(np.sqrt(unseen_test_gm_separate))
          all_train_gms['shared'].append(train_gm)
          all_test_gms['shared'].append(test_gm)
          all_unseen_test_gms['shared'].append(np.sqrt(unseen_test_gm))



      all_train_all[ARCH + ' ' +'separate'].append(np.sqrt(train_gm_separate))
      all_test_all[ARCH + ' ' +'separate'].append(np.sqrt(test_gm_separate))
      all_unseen_test_all[ARCH + ' ' +'separate'].append(np.sqrt(unseen_test_gm_separate))
      all_train_all[ARCH + ' ' +'shared'].append(train_gm)
      all_test_all[ARCH + ' ' +'shared'].append(test_gm)
      all_unseen_test_all[ARCH + ' ' +'shared'].append(np.sqrt(unseen_test_gm))
      print(all_train_all)

      



      # fig,ax = plt.subplots(1, 3, figsize=(18,6))
      # fig.suptitle(dataset_titles[DATASET_NAME], fontsize = 30)
      # l1 = ax[0].plot(all_train_gms['separate'], color = 'blue', marker = 'o', markersize=5)[0]
      # l2 = ax[0].plot(all_train_gms['shared'], color = 'red', marker = 'o', markersize=5)[0]
      # ax[0].set_title('Train Accuracy', fontsize=12)
      # line_labels = ["Separate", "Shared"]

      # ax[1].plot(all_test_gms['separate'], color = 'blue', marker = 'o', markersize=5)
      # ax[1].plot(all_test_gms['shared'], color = 'red', marker = 'o', markersize=5)
      # ax[1].set_title('Test Accuracy on Seen \n Category-Viewpoint Combinations', fontsize=12)

      # ax[2].plot(all_unseen_test_gms['separate'], color = 'blue', marker = 'o', markersize=5)
      # ax[2].plot(all_unseen_test_gms['shared'], color = 'red', marker = 'o', markersize=5)
      # ax[2].set_title('Test Accuracy on Unseen \n Category-Viewpoint Combinations', fontsize=12)
      # fig.legend([l1, l2],     # The line objects
      #         labels=line_labels,   # The labels for each line
      #         loc="center right",   # Position of legend
      #         borderaxespad=0.2,    # Small spacing around legend box
      #         prop={"size":20})
      # plt.subplots_adjust(right=0.85, top =0.80)
      # plt.show()
# Out:
# ______________________________________________________
# model_name: acgan   comb_name 20% combinations seen
# Epoch: 0, Task: viewpoint
# ---------
# Epoch: 0, Task: category
# ---------
# Epoch: 0, Task: shared
# ---------
# Epoch: 1, Task: viewpoint
# ---------
# Epoch: 1, Task: category
# ---------
# Epoch: 1, Task: shared
# ---------
# {'acgan shared': [0.19088235294117648], 'acgan separate': [0.201314452165062]}
# ______________________________________________________
# model_name: acgan   comb_name 40% combinations seen
# Epoch: 0, Task: viewpoint
# ---------
# Epoch: 0, Task: category
# ---------
# Epoch: 0, Task: shared
# ---------
# Epoch: 1, Task: viewpoint
# ---------
# Epoch: 1, Task: category
# ---------
# Epoch: 1, Task: shared
# ---------
# {'acgan shared': [0.19088235294117648, 0.2182321230148553], 'acgan separate': [0.201314452165062, 0.22335209685505567]}
# ______________________________________________________
# model_name: acgan   comb_name 60% combinations seen
# Epoch: 0, Task: viewpoint
# ---------
# Epoch: 0, Task: category
# ---------
# Epoch: 0, Task: shared
# ---------
# Epoch: 1, Task: viewpoint
# ---------
# Epoch: 1, Task: category
# ---------
# Epoch: 1, Task: shared
# ---------
# {'acgan shared': [0.19088235294117648, 0.2182321230148553, 0.20778240881211457], 'acgan separate': [0.201314452165062, 0.22335209685505567, 0.21762718510218737]}
# ______________________________________________________
# model_name: acgan   comb_name 80% combinations seen
# Epoch: 0, Task: viewpoint
# ---------
# Epoch: 0, Task: category
# ---------
# Epoch: 0, Task: shared
# ---------
# Epoch: 1, Task: viewpoint
# ---------
# Epoch: 1, Task: category
# ---------
# Epoch: 1, Task: shared
# ---------
# {'acgan shared': [0.19088235294117648, 0.2182321230148553, 0.20778240881211457, 0.1964333797101701], 'acgan separate': [0.201314452165062, 0.22335209685505567, 0.21762718510218737, 0.20364838413270456]}
# ______________________________________________________
# model_name: wgan   comb_name 20% combinations seen
# Epoch: 0, Task: viewpoint
# ---------
# Epoch: 0, Task: category
# ---------
# Epoch: 0, Task: shared
# ---------
# Epoch: 1, Task: viewpoint
# ---------
# Epoch: 1, Task: category
# ---------
# Epoch: 1, Task: shared
# ---------
# {'acgan shared': [0.19088235294117648, 0.2182321230148553, 0.20778240881211457, 0.1964333797101701], 'acgan separate': [0.201314452165062, 0.22335209685505567, 0.21762718510218737, 0.20364838413270456], 'wgan shared': [0.20823529411764705], 'wgan separate': [0.20569108762756777]}
# ______________________________________________________
# model_name: wgan   comb_name 40% combinations seen
# Epoch: 0, Task: viewpoint
# ---------
# Epoch: 0, Task: category
# ---------
# Epoch: 0, Task: shared
# ---------
# Epoch: 1, Task: viewpoint
# ---------
# Epoch: 1, Task: category
# ---------
# Epoch: 1, Task: shared
# ---------
# {'acgan shared': [0.19088235294117648, 0.2182321230148553, 0.20778240881211457, 0.1964333797101701], 'acgan separate': [0.201314452165062, 0.22335209685505567, 0.21762718510218737, 0.20364838413270456], 'wgan shared': [0.20823529411764705, 0.2181780089711516], 'wgan separate': [0.20569108762756777, 0.2188164135465396]}
# ______________________________________________________
# model_name: wgan   comb_name 60% combinations seen
# Epoch: 0, Task: viewpoint
# ---------
# Epoch: 0, Task: category
# ---------
# Epoch: 0, Task: shared
# ---------
# Epoch: 1, Task: viewpoint
# ---------
# Epoch: 1, Task: category
# ---------
# Epoch: 1, Task: shared
# ---------
# {'acgan shared': [0.19088235294117648, 0.2182321230148553, 0.20778240881211457, 0.1964333797101701], 'acgan separate': [0.201314452165062, 0.22335209685505567, 0.21762718510218737, 0.20364838413270456], 'wgan shared': [0.20823529411764705, 0.2181780089711516, 0.19496251081384178], 'wgan separate': [0.20569108762756777, 0.2188164135465396, 0.20146285944814796]}
# ______________________________________________________
# model_name: wgan   comb_name 80% combinations seen
# Epoch: 0, Task: viewpoint
# ---------
# Epoch: 0, Task: category
# ---------
# Epoch: 0, Task: shared
# ---------
# Epoch: 1, Task: viewpoint
# ---------
# Epoch: 1, Task: category
# ---------
# Epoch: 1, Task: shared
# ---------
# {'acgan shared': [0.19088235294117648, 0.2182321230148553, 0.20778240881211457, 0.1964333797101701], 'acgan separate': [0.201314452165062, 0.22335209685505567, 0.21762718510218737, 0.20364838413270456], 'wgan shared': [0.20823529411764705, 0.2181780089711516, 0.19496251081384178, 0.1966160521735658], 'wgan separate': [0.20569108762756777, 0.2188164135465396, 0.20146285944814796, 0.20488835680517636]}
# ______________________________________________________
# model_name: sgan   comb_name 20% combinations seen
# Epoch: 0, Task: viewpoint
# ---------
# Epoch: 0, Task: category
# ---------
# Epoch: 0, Task: shared
# ---------
# Epoch: 1, Task: viewpoint
# ---------
# Epoch: 1, Task: category
# ---------
# Epoch: 1, Task: shared
# ---------
# {'acgan shared': [0.19088235294117648, 0.2182321230148553, 0.20778240881211457, 0.1964333797101701], 'acgan separate': [0.201314452165062, 0.22335209685505567, 0.21762718510218737, 0.20364838413270456], 'wgan shared': [0.20823529411764705, 0.2181780089711516, 0.19496251081384178, 0.1966160521735658], 'wgan separate': [0.20569108762756777, 0.2188164135465396, 0.20146285944814796, 0.20488835680517636], 'sgan shared': [0.2011764705882353], 'sgan separate': [0.2068615370283468]}
# ______________________________________________________
# model_name: sgan   comb_name 40% combinations seen
# Epoch: 0, Task: viewpoint
# ---------
# Epoch: 0, Task: category
# ---------
# Epoch: 0, Task: shared
# ---------
# Epoch: 1, Task: viewpoint
# ---------
# Epoch: 1, Task: category
# ---------
# Epoch: 1, Task: shared
# ---------
# {'acgan shared': [0.19088235294117648, 0.2182321230148553, 0.20778240881211457, 0.1964333797101701], 'acgan separate': [0.201314452165062, 0.22335209685505567, 0.21762718510218737, 0.20364838413270456], 'wgan shared': [0.20823529411764705, 0.2181780089711516, 0.19496251081384178, 0.1966160521735658], 'wgan separate': [0.20569108762756777, 0.2188164135465396, 0.20146285944814796, 0.20488835680517636], 'sgan shared': [0.2011764705882353, 0.21777420769304198], 'sgan separate': [0.2068615370283468, 0.21470568090240347]}
# ______________________________________________________
# model_name: sgan   comb_name 60% combinations seen
# Epoch: 0, Task: viewpoint
# ---------
# Epoch: 0, Task: category
# ---------
# Epoch: 0, Task: shared
# ---------
# Epoch: 1, Task: viewpoint
# ---------
# Epoch: 1, Task: category
# ---------
# Epoch: 1, Task: shared
# ---------
# {'acgan shared': [0.19088235294117648, 0.2182321230148553, 0.20778240881211457, 0.1964333797101701], 'acgan separate': [0.201314452165062, 0.22335209685505567, 0.21762718510218737, 0.20364838413270456], 'wgan shared': [0.20823529411764705, 0.2181780089711516, 0.19496251081384178, 0.1966160521735658], 'wgan separate': [0.20569108762756777, 0.2188164135465396, 0.20146285944814796, 0.20488835680517636], 'sgan shared': [0.2011764705882353, 0.21777420769304198, 0.20661717605137858], 'sgan separate': [0.2068615370283468, 0.21470568090240347, 0.20705882352941177]}
# ______________________________________________________
# model_name: sgan   comb_name 80% combinations seen
# Epoch: 0, Task: viewpoint
# ---------
# Epoch: 0, Task: category
# ---------
# Epoch: 0, Task: shared
# ---------
# Epoch: 1, Task: viewpoint
# ---------
# Epoch: 1, Task: category
# ---------
# Epoch: 1, Task: shared
# ---------
# {'acgan shared': [0.19088235294117648, 0.2182321230148553, 0.20778240881211457, 0.1964333797101701], 'acgan separate': [0.201314452165062, 0.22335209685505567, 0.21762718510218737, 0.20364838413270456], 'wgan shared': [0.20823529411764705, 0.2181780089711516, 0.19496251081384178, 0.1966160521735658], 'wgan separate': [0.20569108762756777, 0.2188164135465396, 0.20146285944814796, 0.20488835680517636], 'sgan shared': [0.2011764705882353, 0.21777420769304198, 0.20661717605137858, 0.18746949002059327], 'sgan separate': [0.2068615370283468, 0.21470568090240347, 0.20705882352941177, 0.20343801075869103]}

# %%
percentage = [0.2, 0.4, 0.6, 0.8]

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
label = []
for key, value in all_train_all.items():
    if 'separate' in key:
        sns.lineplot(ax=axes[0, 0], y = value, x =  percentage)
        label.append(key)

axes[0, 0].legend(label)
axes[0, 0].set_title('biased_car_train acc of different GAN models (separate)')
label = []        

for key, value in all_test_all.items():
    if 'separate' in key:
        sns.lineplot(ax=axes[0, 1], y = value, x =  percentage)
        label.append(key)

axes[0, 1].legend(label)
axes[0, 1].set_title('biased_car_test acc of different GAN models (separate)')

label = []    

for key, value in all_unseen_test_all.items():
    if 'separate' in key:   
        sns.lineplot(ax=axes[0, 2], y = value, x =  percentage)
        label.append(key)

axes[0, 2].legend(label)
axes[0, 2].set_title('biased_car_unseen_test acc of different GAN models (separate)')

label = []   


for key, value in all_train_all.items():
    if 'share' in key:
        sns.lineplot(ax=axes[1, 0], y = value, x =  percentage)
        label.append(key)

axes[1, 0].legend(label)
axes[1, 0].set_title('biased_car_train acc of different GAN models (share)')
label = []        

for key, value in all_test_all.items():
    if 'share' in key:
        sns.lineplot(ax=axes[1, 1], y = value, x =  percentage)
        label.append(key)

axes[1, 1].legend(label)
axes[1, 1].set_title('biased_car_test acc of different GAN models (share)')

label = []    

for key, value in all_unseen_test_all.items():
    if 'share' in key:   
        sns.lineplot(ax=axes[1, 2], y = value, x =  percentage)
        label.append(key)

axes[1, 2].legend(label)
axes[1, 2].set_title('biased_car_unseen_test acc of different GAN models (share)')

label = []   









# axes[0, 0].legend(label)
# axes[0, 1].legend(label)
# axes[0, 0].set_title('111')
plt.setp(axes[-1, :], xlabel='percentage of combination')
plt.setp(axes[:, 0], ylabel='acc')
# axes[0, 0].('percentage of combination')
# axes.set_xlabels('percentage of combination')
# # axes[0, 0].ylabel('acc')
# # set_axis_labels
# axes.title('mnist_train acc of different GAN models (separate)')
# Out:
# [Text(0, 0.5, 'acc'), Text(0, 0.5, 'acc')]

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 6))
label = []
for key, value in all_test_all.items():
    if 'wgan' in key:
        sns.lineplot(ax=axes[0], y = value, x =  percentage)
        label.append(key)

axes[0].legend(label)
axes[0].set_title('biased_car_test acc of wgan models')
label = []        

for key, value in all_test_all.items():
    if 'acgan' in key:
        sns.lineplot(ax=axes[1], y = value, x =  percentage)
        label.append(key)

axes[1].legend(label)
axes[1].set_title('biased_car_test acc of acgan models')

label = []    

for key, value in all_test_all.items():
    if 'sgan' in key:   
        sns.lineplot(ax=axes[2], y = value, x =  percentage)
        label.append(key)

axes[2].legend(label)
axes[2].set_title('biased_car_test acc of different GAN models')

label = []   











plt.setp(axes[:], xlabel='percentage of combination')
plt.setp(axes[0], ylabel='acc')
# Out:
# [Text(0, 0.5, 'acc')]

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 6))
label = []
for key, value in all_unseen_test_all.items():
    if 'wgan' in key:
        sns.lineplot(ax=axes[0], y = value, x =  percentage)
        label.append(key)

axes[0].legend(label)
axes[0].set_title('biased_car_unseen_test acc of wgan models')
label = []        

for key, value in all_unseen_test_all.items():
    if 'acgan' in key:
        sns.lineplot(ax=axes[1], y = value, x =  percentage)
        label.append(key)

axes[1].legend(label)
axes[1].set_title('biased_car_unseen_test acc of acgan models')

label = []    

for key, value in all_unseen_test_all.items():
    if 'sgan' in key:   
        sns.lineplot(ax=axes[2], y = value, x =  percentage)
        label.append(key)

axes[2].legend(label)
axes[2].set_title('biased_car_unseen_test acc of different GAN models')

label = []   











plt.setp(axes[:], xlabel='percentage of combination')
plt.setp(axes[0], ylabel='acc')
# Out:
# [Text(0, 0.5, 'acc')]
